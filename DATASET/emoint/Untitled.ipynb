# %%
import pandas as pd
import re
# !python3 -m pip install nltk

# %%
import nltk
#nltk.download()
nltk.download([
...     "names",
...     "stopwords",
...     "state_union",
...     "twitter_samples",
...     "movie_reviews",
...     "averaged_perceptron_tagger",
...     "vader_lexicon",
...     "punkt",
... ])
# Out:
#   File "/var/folders/cd/q85hkwv14wx66rw3c3cqw_n80000gn/T/ipykernel_41674/2189213762.py", line 4
#     ...     "names",
#             ^
# SyntaxError: invalid syntax

# %%
import numpy as np
import spacy as sp
# !python -m spacy download en_core_web_sm
# Out:
# INFO:tensorflow:Enabling eager execution
# INFO:tensorflow:Enabling v2 tensorshape
# INFO:tensorflow:Enabling resource variables
# INFO:tensorflow:Enabling tensor equality
# INFO:tensorflow:Enabling control flow v2
# ...
#      |████████████████████████████████| 13.6 MB 864 kB/s eta 0:00:01
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
nlp=sp.load('en_core_web_sm')

# %%
data = pd.read_csv('../emoint/anger-ratings-0to1.dev.target.txt',sep='\t')

# %%
data
# Out:
#     10857  @ZubairSabirPTI  pls dont insult the word 'Molna'  anger  NONE
# 0   10858  @ArcticFantasy I would have almost took offens...  anger  NONE
# 1   10859  @IllinoisLoyalty that Rutgers game was an abom...  anger  NONE
# 2   10860  @CozanGaming that's what lisa asked before she...  anger  NONE
# 3   10861  Sometimes I get mad over something so minuscul...  anger  NONE
# 4   10862  Sometimes I get mad over something so minuscul...  anger  NONE
# ..    ...                                                ...    ...   ...
# 78  10936  @Jen_ny69 People will always get offended ever...  anger  NONE
# 79  10937  @gayla_weeks1 I try not to let my anger seep i...  anger  NONE
# 80  10938               I hope my hustle don't offend nobody  anger  NONE
# 81  10939  Just watched Django Unchained, Other people ma...  anger  NONE
# 82  10940     Lol little things like that make me so angry x  anger  NONE
#
# [83 rows x 4 columns]

# %%
data = pd.read_csv('../emoint/emoint_all',sep='\t')

# %%
data.describe()
# Out:
#               10857
# count   7101.000000
# mean   25108.972962
# std    10692.040843
# min    10000.000000
# 25%    20075.000000
# 50%    21850.000000
# 75%    31373.000000
# max    41532.000000

# %%
data.shape
# Out:
# (7101, 4)

# %%
data.head()
# Out:
#    10857  @ZubairSabirPTI  pls dont insult the word 'Molna'  anger  NONE
# 0  10858  @ArcticFantasy I would have almost took offens...  anger  NONE
# 1  10859  @IllinoisLoyalty that Rutgers game was an abom...  anger  NONE
# 2  10860  @CozanGaming that's what lisa asked before she...  anger  NONE
# 3  10861  Sometimes I get mad over something so minuscul...  anger  NONE
# 4  10862  Sometimes I get mad over something so minuscul...  anger  NONE

# %%
data.tail()
# Out:
#       10857  @ZubairSabirPTI  pls dont insult the word 'Molna'    anger   NONE
# 7096  40781  @VivienLloyd Thank you so much! Just home - st...  sadness  0.104
# 7097  40782              Just put the winter duvet on ☃️❄️🌬☔️   sadness  0.104
# 7098  40783  @SilkInSide @TommyJoeRatliff that's so pretty!...  sadness  0.088
# 7099  40784  @BluesfestByron second artist announcement loo...  sadness  0.083
# 7100  40785  I can literally eat creamy pesto pasta topped ...  sadness  0.083

# %%
data = pd.read_csv('../emoint/emoint_all', sep='\t')

# %%
data.head(100)
# Out:
#     10857  @ZubairSabirPTI  pls dont insult the word 'Molna'  anger   NONE
# 0   10858  @ArcticFantasy I would have almost took offens...  anger   NONE
# 1   10859  @IllinoisLoyalty that Rutgers game was an abom...  anger   NONE
# 2   10860  @CozanGaming that's what lisa asked before she...  anger   NONE
# 3   10861  Sometimes I get mad over something so minuscul...  anger   NONE
# 4   10862  Sometimes I get mad over something so minuscul...  anger   NONE
# ..    ...                                                ...    ...    ...
# 95  10953  @EtherealMystic_ She was winning this war that...  anger  0.333
# 96  10954  They gonna give this KKk police bitch the mini...  anger  0.877
# 97  10955  They gonna give this KKk police bitch the mini...  anger  0.708
# 98  10956                   I just got murdered in madden. 🤕  anger  0.417
# 99  10957  My nephew sees that i have a frown on my face ...  anger  0.229
#
# [100 rows x 4 columns]

# %%
data.tail(100)
# Out:
#       10857  @ZubairSabirPTI  pls dont insult the word 'Molna'    anger   NONE
# 7001  40686  I added Paul Walker on Xbox but he just spends...  sadness  0.271
# 7002  40687  How much time should I give to my friend who l...  sadness  0.271
# 7003  40688       i can't take u #serious unless u use #emojis  sadness  0.271
# 7004  40689  Back to forest drama -\nfrom my #Forest #music...  sadness  0.271
# 7005  40690  @makai_kishi_ Her eyes stayed glued to the mon...  sadness  0.271
# ...     ...                                                ...      ...    ...
# 7096  40781  @VivienLloyd Thank you so much! Just home - st...  sadness  0.104
# 7097  40782              Just put the winter duvet on ☃️❄️🌬☔️   sadness  0.104
# 7098  40783  @SilkInSide @TommyJoeRatliff that's so pretty!...  sadness  0.088
# 7099  40784  @BluesfestByron second artist announcement loo...  sadness  0.083
# 7100  40785  I can literally eat creamy pesto pasta topped ...  sadness  0.083
#
# [100 rows x 4 columns]

# %%
data.shape
# Out:
# (7101, 4)

# %%
data.describe(include=object)
# Out:
#         @ZubairSabirPTI  pls dont insult the word 'Molna' anger  NONE
# count                                                7101  7101  7101
# unique                                               6907     4   545
# top     Just watched Django Unchained, Other people ma...  fear  NONE
# freq                                                    3  2252   346

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
len(data)
# Out:
# 7101

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7101 entries, 0 to 7100
# Data columns (total 4 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   10857                                              7101 non-null   int64
#  1   @ZubairSabirPTI  pls dont insult the word 'Molna'  7101 non-null   object
#  2   anger                                              7101 non-null   object
#  3   NONE                                               7101 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 222.0+ KB

# %%
df=data

# %%
df1 = df.rename(
    columns={"10857": "id","@ZubairSabirPTI pls dont insult the word 'Molna'":"intent","anger":"Label","NONE":"Score"},
inplace=False
)

# %%
df1.rename(
    columns={"@ZubairSabirPTI pls dont insult the word 'Molna'":""}

)
# Out:
#          id  @ZubairSabirPTI  pls dont insult the word 'Molna'    Label  Score
# 0     10858  @ArcticFantasy I would have almost took offens...    anger   NONE
# 1     10859  @IllinoisLoyalty that Rutgers game was an abom...    anger   NONE
# 2     10860  @CozanGaming that's what lisa asked before she...    anger   NONE
# 3     10861  Sometimes I get mad over something so minuscul...    anger   NONE
# 4     10862  Sometimes I get mad over something so minuscul...    anger   NONE
# ...     ...                                                ...      ...    ...
# 7096  40781  @VivienLloyd Thank you so much! Just home - st...  sadness  0.104
# 7097  40782              Just put the winter duvet on ☃️❄️🌬☔️   sadness  0.104
# 7098  40783  @SilkInSide @TommyJoeRatliff that's so pretty!...  sadness  0.088
# 7099  40784  @BluesfestByron second artist announcement loo...  sadness  0.083
# 7100  40785  I can literally eat creamy pesto pasta topped ...  sadness  0.083
#
# [7101 rows x 4 columns]

# %%
df1.drop("id",axis=1)
# Out:
#       @ZubairSabirPTI  pls dont insult the word 'Molna'    Label  Score
# 0     @ArcticFantasy I would have almost took offens...    anger   NONE
# 1     @IllinoisLoyalty that Rutgers game was an abom...    anger   NONE
# 2     @CozanGaming that's what lisa asked before she...    anger   NONE
# 3     Sometimes I get mad over something so minuscul...    anger   NONE
# 4     Sometimes I get mad over something so minuscul...    anger   NONE
# ...                                                 ...      ...    ...
# 7096  @VivienLloyd Thank you so much! Just home - st...  sadness  0.104
# 7097              Just put the winter duvet on ☃️❄️🌬☔️   sadness  0.104
# 7098  @SilkInSide @TommyJoeRatliff that's so pretty!...  sadness  0.088
# 7099  @BluesfestByron second artist announcement loo...  sadness  0.083
# 7100  I can literally eat creamy pesto pasta topped ...  sadness  0.083
#
# [7101 rows x 3 columns]

# %%
df2=df1.drop(["id","Score"],axis=1)

# %%
df2.columns=['Intents','Label']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7101 entries, 0 to 7100
# Data columns (total 4 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   10857                                              7101 non-null   int64
#  1   @ZubairSabirPTI  pls dont insult the word 'Molna'  7101 non-null   object
#  2   anger                                              7101 non-null   object
#  3   NONE                                               7101 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 222.0+ KB

# %%
df.columns=["id","Intent","Label","Score"]

# %%
df
# Out:
#          id                                             Intent    Label  Score
# 0     10858  @ArcticFantasy I would have almost took offens...    anger   NONE
# 1     10859  @IllinoisLoyalty that Rutgers game was an abom...    anger   NONE
# 2     10860  @CozanGaming that's what lisa asked before she...    anger   NONE
# 3     10861  Sometimes I get mad over something so minuscul...    anger   NONE
# 4     10862  Sometimes I get mad over something so minuscul...    anger   NONE
# ...     ...                                                ...      ...    ...
# 7096  40781  @VivienLloyd Thank you so much! Just home - st...  sadness  0.104
# 7097  40782              Just put the winter duvet on ☃️❄️🌬☔️   sadness  0.104
# 7098  40783  @SilkInSide @TommyJoeRatliff that's so pretty!...  sadness  0.088
# 7099  40784  @BluesfestByron second artist announcement loo...  sadness  0.083
# 7100  40785  I can literally eat creamy pesto pasta topped ...  sadness  0.083
#
# [7101 rows x 4 columns]

# %%
df=df.drop(['id','Score'],axis=1)

# %%
df
# Out:
#                                                  Intent    Label
# 0     @ArcticFantasy I would have almost took offens...    anger
# 1     @IllinoisLoyalty that Rutgers game was an abom...    anger
# 2     @CozanGaming that's what lisa asked before she...    anger
# 3     Sometimes I get mad over something so minuscul...    anger
# 4     Sometimes I get mad over something so minuscul...    anger
# ...                                                 ...      ...
# 7096  @VivienLloyd Thank you so much! Just home - st...  sadness
# 7097              Just put the winter duvet on ☃️❄️🌬☔️   sadness
# 7098  @SilkInSide @TommyJoeRatliff that's so pretty!...  sadness
# 7099  @BluesfestByron second artist announcement loo...  sadness
# 7100  I can literally eat creamy pesto pasta topped ...  sadness
#
# [7101 rows x 2 columns]

# %%
df.to_csv('Emo1.csv', header= True, index=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7101 entries, 0 to 7100
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Intent  7101 non-null   object
#  1   Label   7101 non-null   object
# dtypes: object(2)
# memory usage: 111.1+ KB

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#                                               Intent  Label
# 0  @ArcticFantasy I would have almost took offens...  anger
# 1  @IllinoisLoyalty that Rutgers game was an abom...  anger
# 2  @CozanGaming that's what lisa asked before she...  anger
# 3  Sometimes I get mad over something so minuscul...  anger
# 4  Sometimes I get mad over something so minuscul...  anger

# %%
df.tail()
# Out:
#                                                  Intent    Label
# 7096  @VivienLloyd Thank you so much! Just home - st...  sadness
# 7097              Just put the winter duvet on ☃️❄️🌬☔️   sadness
# 7098  @SilkInSide @TommyJoeRatliff that's so pretty!...  sadness
# 7099  @BluesfestByron second artist announcement loo...  sadness
# 7100  I can literally eat creamy pesto pasta topped ...  sadness

# %%
len(df)
# Out:
# 7101

# %%
df.shape
# Out:
# (7101, 2)

# %%
df.describe()
# Out:
#                                                    Intent Label
# count                                                7101  7101
# unique                                               6907     4
# top     Just watched Django Unchained, Other people ma...  fear
# freq                                                    3  2252

# %%
df['Label']
# Out:
# 0         anger
# 1         anger
# 2         anger
# 3         anger
# 4         anger
#          ...
# 7096    sadness
# 7097    sadness
# 7098    sadness
# 7099    sadness
# 7100    sadness
# Name: Label, Length: 7101, dtype: object

# %%
df['Label'].nunique()
# Out:
# 4

# %%
df['Label'].value_counts()
# Out:
# fear       2252
# anger      1700
# joy        1616
# sadness    1533
# Name: Label, dtype: int64

# %%
df['Intent'].nunique()
# Out:
# 6907

# %%
df['Intent'].value_counts().head()
# Out:
# Just watched Django Unchained, Other people may frown, but I titter in delight! 2/5                                                     3
# @iTriborg — make him feel vigorous. 'Fine. You can kill me now.' Said Hestia with a display of only despair rather than her joyful —    3
# For a team as big as Bayern and the they like to play football, their pitch is fucking dreadful. Certainly no Emirates pitch anyway.    2
# @Markgatiss I'm surrounded by those Trump voters. You're right, it is fucking terrifying. #redstate #despair                            2
# one ep of despair arc made me happy but and then i'm going back to future arc and i'm upset again.                                      2
# Name: Intent, dtype: int64

# %%
df['Label']=pd.Categorical(df['Label'])

# %%
df['Label'].dtype
# Out:
# CategoricalDtype(categories=['anger', 'fear', 'joy', 'sadness'], ordered=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7101 entries, 0 to 7100
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Intent  7101 non-null   object
#  1   Label   7101 non-null   category
# dtypes: category(1), object(1)
# memory usage: 62.7+ KB

# %%
grouped = df.groupby(df.Label)

# %%
df_anger= grouped.get_group("anger")
df_anger
# Out:
#                                                  Intent  Label
# 0     @ArcticFantasy I would have almost took offens...  anger
# 1     @IllinoisLoyalty that Rutgers game was an abom...  anger
# 2     @CozanGaming that's what lisa asked before she...  anger
# 3     Sometimes I get mad over something so minuscul...  anger
# 4     Sometimes I get mad over something so minuscul...  anger
# ...                                                 ...    ...
# 1695   rose incense are the best thing I've ever bought  anger
# 1696         @jaaames1993 Literally burst out laughing.  anger
# 1697           Follow up. Follow through. Be . #success  anger
# 1698  Wrinkles should merely hide where frown have b...  anger
# 1699  Love the new song I can't stop thinking about ...  anger
#
# [1700 rows x 2 columns]

# %%
df_fear= grouped.get_group("fear")
df_fear
# Out:
#                                                  Intent Label
# 1700  I know this is going to be one of those nights...  fear
# 1701  This is #horrible: Lewis Dunk has begun networ...  fear
# 1702  @JeffersonLake speaking of ex cobblers, saw Ri...  fear
# 1703  @1johndes ball watching &amp; Rojo'd header wa...  fear
# 1704  Really.....#Jumanji 2....w/ The Rock, Jack Bla...  fear
# ...                                                 ...   ...
# 3947     Pull over #tonight and make your car #shake 😋💦  fear
# 3948  @Melanie_Pierce @HunterHayes awe ain't he a sw...  fear
# 3949         @FraserKeegan just had a steak pie supper   fear
# 3950      @annalisewrobel_ awe thank you so much love 💕  fear
# 3951                             Omg he kissed her🙈  #w  fear
#
# [2252 rows x 2 columns]

# %%
df_joy= grouped.get_group("joy")
df_joy
# Out:
#                                                  Intent Label
# 3952  @theclobra lol I thought maybe, couldn't decid...   joy
# 3953  Nawaz Sharif is getting more funnier than @kap...   joy
# 3954  Nawaz Sharif is getting more funnier than @kap...   joy
# 3955  @tomderivan73 😁...I'll just people watch and e...   joy
# 3956  I love my family so much #lucky #grateful #sma...   joy
# ...                                                 ...   ...
# 5563  It's just the lack of company and liveliness o...   joy
# 5564             Quinn's short hair makes me sad. #glee   joy
# 5565  hate overthinking e v e r y t h i n g like i j...   joy
# 5566  People who cheer for sports teams completely o...   joy
# 5567  @DamnPatriot You're a POS for rejoicing in som...   joy
#
# [1616 rows x 2 columns]

# %%
df_sadness=grouped.get_group("sadness")
df_sadness
# Out:
#                                                  Intent    Label
# 5568  @1johndes ball watching &amp; Rojo'd header wa...  sadness
# 5569  A pessimist is someone who, when opportunity k...  sadness
# 5570  A .500 season is all I'm looking for at this p...  sadness
# 5571  Stars, when you shine,\nYou know how I feel.\n...  sadness
# 5572  All I want to do is watch some netflix but I a...  sadness
# ...                                                 ...      ...
# 7096  @VivienLloyd Thank you so much! Just home - st...  sadness
# 7097              Just put the winter duvet on ☃️❄️🌬☔️   sadness
# 7098  @SilkInSide @TommyJoeRatliff that's so pretty!...  sadness
# 7099  @BluesfestByron second artist announcement loo...  sadness
# 7100  I can literally eat creamy pesto pasta topped ...  sadness
#
# [1533 rows x 2 columns]

# %%
df_sa=df_sadness
clmn = list(df_sa)

clmn
# Out:
# ['Intent', 'Label']

# %%
for i in clmn:
    # printing a third element of column
    print(df_sa[i][7100])
# Out:
# I can literally eat creamy pesto pasta topped with grilled chicken, sun dried tomatoes, asparagus and pine nuts every single day of my life
# sadness

# %%
for i in df_sa.itertuples():
    print(i)
# Out:
# Pandas(Index=5568, Intent="@1johndes ball watching &amp; Rojo'd header was equally dreadful!!", Label='sadness')
# Pandas(Index=5569, Intent='A pessimist is someone who, when opportunity knocks, complains about the noise #mikeshumor', Label='sadness')
# Pandas(Index=5570, Intent="A .500 season is all I'm looking for at this point. #depressing #royals", Label='sadness')
# Pandas(Index=5571, Intent="Stars, when you shine,\\nYou know how I feel.\\nScent of the pine, \\nYou know how I feel.\\nFreedom is mine,\\nI know how I feel.\\nI'm feelin' good.", Label='sadness')
# Pandas(Index=5572, Intent='All I want to do is watch some netflix but I am stuck here in class. #depressing', Label='sadness')
# Pandas(Index=5573, Intent="Buddha doesn't possess enough power to deliver you from your affliction!", Label='sadness')
# Pandas(Index=5574, Intent='Donating to Trump puts a damper on a very exciting @Cubs season. Really bad look, Ricketts family.', Label='sadness')
# ...

# %%
for key, value in df_sadness.iteritems():
    print(key, value)
    print()
# Out:
# Intent 5568    @1johndes ball watching &amp; Rojo'd header wa...
# 5569    A pessimist is someone who, when opportunity k...
# 5570    A .500 season is all I'm looking for at this p...
# 5571    Stars, when you shine,\nYou know how I feel.\n...
# 5572    All I want to do is watch some netflix but I a...
#                               ...
# 7096    @VivienLloyd Thank you so much! Just home - st...
# 7097                Just put the winter duvet on ☃️❄️🌬☔️
# 7098    @SilkInSide @TommyJoeRatliff that's so pretty!...
# 7099    @BluesfestByron second artist announcement loo...
# 7100    I can literally eat creamy pesto pasta topped ...
# Name: Intent, Length: 1533, dtype: object
#
# Label 5568    sadness
# 5569    sadness
# 5570    sadness
# 5571    sadness
# 5572    sadness
#          ...
# 7096    sadness
# 7097    sadness
# 7098    sadness
# 7099    sadness
# 7100    sadness
# Name: Label, Length: 1533, dtype: category
# Categories (4, object): ['anger', 'fear', 'joy', 'sadness']

# %%
for i, j in df_sadness.iterrows():
    print(i, j)
    print()
# Out:
# 5568 Intent    @1johndes ball watching &amp; Rojo'd header wa...
# Label                                               sadness
# Name: 5568, dtype: object
#
# 5569 Intent    A pessimist is someone who, when opportunity k...
# Label                                               sadness
# Name: 5569, dtype: object
#
# 5570 Intent    A .500 season is all I'm looking for at this p...
# Label                                               sadness
# Name: 5570, dtype: object
#
# 5571 Intent    Stars, when you shine,\nYou know how I feel.\n...
# Label                                               sadness
# Name: 5571, dtype: object
#
# 5572 Intent    All I want to do is watch some netflix but I a...
# Label                                               sadness
# Name: 5572, dtype: object
#
# 5573 Intent    Buddha doesn't possess enough power to deliver...
# Label                                               sadness
# Name: 5573, dtype: object
#
# ...

# %%
[print(i) for i in df_sadness['Intent']]
# Out:
# @1johndes ball watching &amp; Rojo'd header was equally dreadful!!
# A pessimist is someone who, when opportunity knocks, complains about the noise #mikeshumor
# A .500 season is all I'm looking for at this point. #depressing #royals
# Stars, when you shine,\nYou know how I feel.\nScent of the pine, \nYou know how I feel.\nFreedom is mine,\nI know how I feel.\nI'm feelin' good.
# All I want to do is watch some netflix but I am stuck here in class. #depressing
# Buddha doesn't possess enough power to deliver you from your affliction!
# Donating to Trump puts a damper on a very exciting @Cubs season. Really bad look, Ricketts family.
# Hello my dear friends, I will be back online this Friday night. I miss you! #sober #sobriety #recovery
# @ccrago It was dreadful, even after he met the Catfish he still thought it was her!
# watching this uni reveal is so depressing i miss stingrays :(
# Public products: high downhearted price tag consumer survey sum and substance: OVth
# ...

# %%
pip install dframcy --user
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import spacy
from dframcy import DframCy
#pip install text2emotion
# Out:
#   File "/var/folders/cd/q85hkwv14wx66rw3c3cqw_n80000gn/T/ipykernel_41674/3206618602.py", line 3
#     pip install text2emotion
#         ^
# SyntaxError: invalid syntax

# %%
pip install text2emotion
# Out:
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#Import the modules
import text2emotion as te
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/PaulGee/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/PaulGee/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /Users/PaulGee/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
text = "I was asked to sign a third party contract a week out from stay. If it wasn't an 8 person group that took a lot of wrangling I would have cancelled the booking straight away. Bathrooms - there are no stand alone bathrooms. Please consider this - you have to clear out the main bedroom to use that bathroom. Other option is you walk through a different bedroom to get to its en-suite. Signs all over the apartment - there are signs everywhere - some helpful - some telling you rules. Perhaps some people like this but It negatively affected our enjoyment of the accommodation. Stairs - lots of them - some had slightly bending wood which caused a minor injury."

# %%
#Call to the function
te.get_emotion(text)
# Out:
# {'Happy': 0.04, 'Angry': 0.12, 'Surprise': 0.08, 'Sad': 0.33, 'Fear': 0.42}

# %%
text = "Day was pretty amazing😃😃"
te.get_emotion(text)
# Out:
# {'Happy': 1.0, 'Angry': 0.0, 'Surprise': 0.0, 'Sad': 0.0, 'Fear': 0.0}

# %%
# Iterating over one column - `f` is some function that processes your data
result = [x for x in (df_sadness['Intent'])]

# %%
result= pd.DataFrame(data=result)

# %%
result.dtypes
# Out:
# 0    object
# dtype: object

# %% [raw]
# result=nlp(result)

# %%
type(result)
# Out:
# pandas.core.frame.DataFrame

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/cd/q85hkwv14wx66rw3c3cqw_n80000gn/T/ipykernel_33459/2378377641.py in <module>
# ----> 1 list(result.sents)[1]
#
# /usr/local/lib/python3.9/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'sents'

# %%
# Iterating over two columns, use `zip`
result = [(x,y) for x,y in zip(df_sadness['Intent'], df_sadness['Label'])]

# %%
print(result)
# Out:
# [("@1johndes ball watching &amp; Rojo'd header was equally dreadful!!", 'sadness'), ('A pessimist is someone who, when opportunity knocks, complains about the noise #mikeshumor', 'sadness'), ("A .500 season is all I'm looking for at this point. #depressing #royals", 'sadness'), ("Stars, when you shine,\\nYou know how I feel.\\nScent of the pine, \\nYou know how I feel.\\nFreedom is mine,\\nI know how I feel.\\nI'm feelin' good.", 'sadness'), ('All I want to do is watch some netflix but I am stuck here in class. #depressing', 'sadness'), ("Buddha doesn't possess enough power to deliver you from your affliction!", 'sadness'), ('Donating to Trump puts a damper on a very exciting @Cubs season. Really bad look, Ricketts family.', 'sadness'), ('Hello my dear friends, I will be back online this Friday night. I miss you! #sober #sobriety #recovery', 'sadness'), ('@ccrago It was dreadful, even after he met the Catfish he still thought it was her!', 'sadness'), ('watching this uni reveal is so
# ...

# %%
# Iterating over multiple columns - differing data type
result = [(row[0],row[1]) for row in zip(df_sadness['Intent'], df_sadness['Label'])]

# %%
nlp(result)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/cd/q85hkwv14wx66rw3c3cqw_n80000gn/T/ipykernel_33459/1368132238.py in <module>
# ----> 1 nlp(result)
#
# /usr/local/lib/python3.9/site-packages/spacy/language.py in __call__(self, text, disable, component_cfg)
#     985         DOCS: https://spacy.io/api/language#call
#     986         """
# --> 987         doc = self.make_doc(text)
#     988         if component_cfg is None:
#     989             component_cfg = {}
#
# /usr/local/lib/python3.9/site-packages/spacy/language.py in make_doc(self, text)
#    1067                 Errors.E088.format(length=len(text), max_length=self.max_length)
#    1068             )
# -> 1069         return self.tokenizer(text)
#    1070
#    1071     def update(
#
# TypeError: Argument 'string' has incorrect type (expected str, got list)
